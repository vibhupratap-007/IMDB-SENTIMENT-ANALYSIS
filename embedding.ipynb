# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From f:\simple_rnn_imdb\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
### Sentences 
sent = [ 'the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the vocabulary size 
voc_size = 10000

# %%
### One Hot Representation 
one_hot_repr = [one_hot(words, voc_size)for words in sent]
one_hot_repr
# Out:
# [[7086, 3329, 8804, 5514],
#  [7086, 3329, 8804, 3460],
#  [7086, 9125, 8804, 6491],
#  [3820, 6253, 3284, 4571, 3355],
#  [3820, 6253, 3284, 4571, 5228],
#  [6814, 7086, 144, 8804, 4898],
#  [7550, 5615, 218, 4571]]

# %%
### Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen = sent_length)  #You can also use post for adding zeros after 
print(embedded_docs)
# Out:
# [[   0    0    0    0 7086 3329 8804 5514]
#  [   0    0    0    0 7086 3329 8804 3460]
#  [   0    0    0    0 7086 9125 8804 6491]
#  [   0    0    0 3820 6253 3284 4571 3355]
#  [   0    0    0 3820 6253 3284 4571 5228]
#  [   0    0    0 6814 7086  144 8804 4898]
#  [   0    0    0    0 7550 5615  218 4571]]

# %%
## Feature representation
dim=10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')
# Out:
# WARNING:tensorflow:From f:\simple_rnn_imdb\venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From f:\simple_rnn_imdb\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 68ms/step
# array([[[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [-0.00928131,  0.02906756, -0.00132401,  0.03712869,
#           0.03117004, -0.00011847,  0.0303526 , -0.01379161,
#          -0.01095513,  0.02704645],
#         [ 0.02776177, -0.00390798, -0.03414539,  0.01012627,
#           0.00860199, -0.01446962,  0.03709468,  0.0328103 ,
#           0.03839842, -0.01867096],
#         [ 0.01648675,  0.01879456,  0.02394334, -0.02448839,
#           0.00944419,  0.01827166,  0.03718462, -0.04898655,
#          -0.01640474, -0.00604621],
#         [ 0.03486634, -0.01501883, -0.02695747, -0.02864809,
#          -0.04484516, -0.04620985, -0.04323522,  0.00547307,
#          -0.00081183,  0.01151063]],
#
#        [[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [-0.00928131,  0.02906756, -0.00132401,  0.03712869,
#           0.03117004, -0.00011847,  0.0303526 , -0.01379161,
#          -0.01095513,  0.02704645],
#         [ 0.02776177, -0.00390798, -0.03414539,  0.01012627,
#           0.00860199, -0.01446962,  0.03709468,  0.0328103 ,
#           0.03839842, -0.01867096],
#         [ 0.01648675,  0.01879456,  0.02394334, -0.02448839,
#           0.00944419,  0.01827166,  0.03718462, -0.04898655,
#          -0.01640474, -0.00604621],
#         [ 0.03533104,  0.04979063, -0.04119109, -0.00772866,
#           0.0142628 ,  0.04596908, -0.02604263, -0.01545929,
#          -0.03446347, -0.04533761]],
#
#        [[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [-0.00928131,  0.02906756, -0.00132401,  0.03712869,
#           0.03117004, -0.00011847,  0.0303526 , -0.01379161,
#          -0.01095513,  0.02704645],
#         [ 0.02897276,  0.02310132,  0.03945113,  0.0184762 ,
#           0.03640256, -0.02769978,  0.01950562,  0.04352223,
#          -0.03202721,  0.01138747],
#         [ 0.01648675,  0.01879456,  0.02394334, -0.02448839,
#           0.00944419,  0.01827166,  0.03718462, -0.04898655,
#          -0.01640474, -0.00604621],
#         [ 0.00428563,  0.04501195,  0.01932604,  0.00922747,
#           0.01879751,  0.03611838, -0.03852411,  0.00822103,
#          -0.02895018,  0.01475156]],
#
#        [[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.02708424,  0.00225401, -0.02891536, -0.04677105,
#           0.00068281, -0.01583959, -0.04739526,  0.02070263,
#           0.01818604, -0.03957094],
#         [ 0.00964317,  0.02765084,  0.04062139,  0.03676596,
#           0.00582854,  0.03465686,  0.02073151, -0.0424532 ,
#           0.00952465, -0.0049237 ],
#         [ 0.02553561,  0.02375301,  0.02847758,  0.00383787,
#           0.03228989,  0.00693886, -0.03951823, -0.04526755,
#           0.01161813, -0.03334277],
#         [ 0.03841224, -0.03248966,  0.00582405,  0.0006633 ,
#           0.04410013, -0.00212771,  0.04507799, -0.02595705,
#          -0.01281289, -0.01714434],
#         [ 0.02901293, -0.00657432, -0.01851296,  0.01281761,
#          -0.03928494, -0.01962079, -0.00413458, -0.00524131,
#           0.02733058, -0.0078273 ]],
#
#        [[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.02708424,  0.00225401, -0.02891536, -0.04677105,
#           0.00068281, -0.01583959, -0.04739526,  0.02070263,
#           0.01818604, -0.03957094],
#         [ 0.00964317,  0.02765084,  0.04062139,  0.03676596,
#           0.00582854,  0.03465686,  0.02073151, -0.0424532 ,
#           0.00952465, -0.0049237 ],
#         [ 0.02553561,  0.02375301,  0.02847758,  0.00383787,
#           0.03228989,  0.00693886, -0.03951823, -0.04526755,
#           0.01161813, -0.03334277],
#         [ 0.03841224, -0.03248966,  0.00582405,  0.0006633 ,
#           0.04410013, -0.00212771,  0.04507799, -0.02595705,
#          -0.01281289, -0.01714434],
#         [ 0.0367906 ,  0.02534362, -0.00558082, -0.04641687,
#           0.0309586 ,  0.01187757,  0.01125482, -0.00214731,
#           0.02552846,  0.04409511]],
#
#        [[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.04952623,  0.03160484,  0.02380929, -0.00684118,
#           0.02008453, -0.04969737,  0.04573191, -0.02340454,
#           0.01432026, -0.01091265],
#         [-0.00928131,  0.02906756, -0.00132401,  0.03712869,
#           0.03117004, -0.00011847,  0.0303526 , -0.01379161,
#          -0.01095513,  0.02704645],
#         [-0.01659268,  0.00238798,  0.00768716, -0.01838984,
#           0.03336315,  0.02743023,  0.0267514 ,  0.01899172,
#           0.02460413,  0.02619758],
#         [ 0.01648675,  0.01879456,  0.02394334, -0.02448839,
#           0.00944419,  0.01827166,  0.03718462, -0.04898655,
#          -0.01640474, -0.00604621],
#         [-0.04970566,  0.03036318, -0.03257891,  0.03938428,
#           0.00223953, -0.02602326,  0.01945878,  0.02754313,
#           0.00411086, -0.0115621 ]],
#
#        [[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,
#           0.00615896,  0.02559922,  0.00569073, -0.02928116,
#          -0.04324067, -0.01642475],
#         [-0.02172548, -0.03123032, -0.01812612, -0.03828186,
#           0.01376181, -0.00924648, -0.04129595, -0.03256991,
#          -0.00811975,  0.02234067],
#         [ 0.04494529, -0.00798493, -0.01245894,  0.01458938,
#          -0.00971937,  0.00733769,  0.02171532,  0.04581953,
#          -0.01859543,  0.04530213],
#         [ 0.00859178,  0.02893373,  0.00104284, -0.01183233,
#          -0.03512276, -0.00140556, -0.01129955, -0.01708591,
#           0.00186773,  0.04973106],
#         [ 0.03841224, -0.03248966,  0.00582405,  0.0006633 ,
#           0.04410013, -0.00212771,  0.04507799, -0.02595705,
#          -0.01281289, -0.01714434]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7086, 3329, 8804, 5514])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 34ms/step
# array([[ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,  0.00615896,
#          0.02559922,  0.00569073, -0.02928116, -0.04324067, -0.01642475],
#        [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,  0.00615896,
#          0.02559922,  0.00569073, -0.02928116, -0.04324067, -0.01642475],
#        [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,  0.00615896,
#          0.02559922,  0.00569073, -0.02928116, -0.04324067, -0.01642475],
#        [ 0.0069278 , -0.00511782,  0.01035545, -0.04816777,  0.00615896,
#          0.02559922,  0.00569073, -0.02928116, -0.04324067, -0.01642475],
#        [-0.00928131,  0.02906756, -0.00132401,  0.03712869,  0.03117004,
#         -0.00011847,  0.0303526 , -0.01379161, -0.01095513,  0.02704645],
#        [ 0.02776177, -0.00390798, -0.03414539,  0.01012627,  0.00860199,
#         -0.01446962,  0.03709468,  0.0328103 ,  0.03839842, -0.01867096],
#        [ 0.01648675,  0.01879456,  0.02394334, -0.02448839,  0.00944419,
#          0.01827166,  0.03718462, -0.04898655, -0.01640474, -0.00604621],
#        [ 0.03486634, -0.01501883, -0.02695747, -0.02864809, -0.04484516,
#         -0.04620985, -0.04323522,  0.00547307, -0.00081183,  0.01151063]],
#       dtype=float32)
